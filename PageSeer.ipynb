# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB, ComplementNB
# import warnings

# from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
def plot_confusion(model, predicted, actual, label = []):
    y_pred = model.predict(predicted)
    y_act = actual
    cm = confusion_matrix(y_act, y_pred, labels = label)
    cm_display = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = label)
    cm_display.plot()
    plt.xticks(rotation='vertical')

# %% [markdown]
# # Part 1: Book Recommendation

# %% [markdown]
# Determine a method of identifying books that are similar to each other. You can use any data available in the “books_data.csv” file, or you can write code to gather more information about each book.

# %% [markdown]
# ## a)

# %% [markdown]
# Write a function that allows a user to search for books similar to one that they specify. Your function should take the name of the book as a parameter and return a list of at least 5 books that are most similar (according to your metric) to the specified book.

# %%
df = pd.read_csv('../data/books_data.csv')

# %%
df = df.dropna(subset=['Title', 'description', 'authors', 'categories']).reset_index(drop=True)
# Convert to strings and clean 'authors' and 'categories' columns
df['authors'] = df['authors'].astype(str).str.replace(r"[\[\]']", "", regex=True)
df['categories'] = df['categories'].astype(str).str.replace(r"[\[\]']", "", regex=True)
df = df.reset_index(drop=True)
# Create 'combination' column
df['combination'] = df['description'].astype(str) + ' ' + df['authors'] + ' ' + df['categories']
# df.head()
# Out:
#                                                Title  \
# 0                           Dr. Seuss: American Icon
# 1              Wonderful Worship in Smaller Churches
# 2                      Whispers of the Wicked Saints
# 3  The Church of Christ: A Biblical Ecclesiology ...
# 4                           Saint Hyacinth of Poland
#
#                                          description               authors  \
# 0  Philip Nel takes a fascinating look into the k...            Philip Nel
# 1  This resource includes twelve principles in un...          David R. Ray
# 2  Julia Thomas finds her life spinning out of co...       Veronica Haddon
# 3  In The Church of Christ: A Biblical Ecclesiolo...      Everett Ferguson
# 4  The story for children 10 and up of St. Hyacin...  Mary Fabyan Windeatt
#
#                                                image  \
# 0  http://books.google.com/books/content?id=IjvHQ...
# 1  http://books.google.com/books/content?id=2tsDA...
# 2  http://books.google.com/books/content?id=aRSIg...
# 3  http://books.google.com/books/content?id=kVqRa...
# 4  http://books.google.com/books/content?id=lmLqA...
#
#                                          previewLink  \
# 0  http://books.google.nl/books?id=IjvHQsCn_pgC&p...
# 1  http://books.google.nl/books?id=2tsDAAAACAAJ&d...
# 2  http://books.google.nl/books?id=aRSIgJlq6JwC&d...
# 3  http://books.google.nl/books?id=kVqRaiPlx88C&p...
# 4  http://books.google.nl/books?id=lmLqAAAACAAJ&d...
#
#                     publisher publishedDate  \
# 0                   A&C Black    2005-01-01
# 1                         NaN          2000
# 2                   iUniverse       2005-02
# 3  Wm. B. Eerdmans Publishing          1996
# 4             Tan Books & Pub    2009-01-01
#
#                                             infoLink  \
# 0  http://books.google.nl/books?id=IjvHQsCn_pgC&d...
# 1  http://books.google.nl/books?id=2tsDAAAACAAJ&d...
# 2  http://books.google.nl/books?id=aRSIgJlq6JwC&d...
# 3  http://books.google.nl/books?id=kVqRaiPlx88C&d...
# 4  http://books.google.nl/books?id=lmLqAAAACAAJ&d...
#
#                   categories  ratingsCount  \
# 0  Biography & Autobiography           NaN
# 1                   Religion           NaN
# 2                    Fiction           NaN
# 3                   Religion           5.0
# 4  Biography & Autobiography           NaN
#
#                                          combination
# 0  Philip Nel takes a fascinating look into the k...
# 1  This resource includes twelve principles in un...
# 2  Julia Thomas finds her life spinning out of co...
# 3  In The Church of Christ: A Biblical Ecclesiolo...
# 4  The story for children 10 and up of St. Hyacin...

# %%
v = CountVectorizer(stop_words = 'english')

X = v.fit_transform(df['combination']) #creates a vocabulary and creates the data

#How toget a movie out of the matrix
df['Title'] == 'Dr. Seuss: American Icon'
idx = df[df['Title'] == 'Dr. Seuss: American Icon'].index[0]
# print(idx)
X[idx]

# Here's a slicker way to do it.
# Generate a mapping from movie title to index in df.
# the pandas Series command works a lot like a built-in python dictionary.
movie2idx = pd.Series(df.index, index=df['Title'])

# %%
from sklearn.metrics.pairwise import cosine_similarity
def get_most_similar(book_title):
    if book_title in movie2idx.keys():
        idx = movie2idx[book_title]
        scores = cosine_similarity(X, X[idx])
        # Now we want to find the best matches. We're not actually interested in the scores themselves, but the relative rankings.
        # For that, we can use the argsort command.
        # scores.argsort() would sort the scores in ascending order and then return the indices that correspond to those scores.
        # Since we want the highest scores, I'll use (-scores).argsort() instead.
        scores = scores.flatten()
        recommended = (-scores).argsort()

        # We should ignore the first entry in the list (since that'll be the movie itself).
        # Let's take the next 5 movies.
        recommended = recommended[1:6]

        # Now we should return the titles of the corresponding movies.
        return df['Title'].iloc[recommended]
    else:
        return "Book not found."

get_most_similar("Wonderful Worship in Smaller Churches")
# Out:
# 11793    A Matter of Honor (G K Hall Large Print Book S...
# 710                     Man of La Mancha;: A musical play,
# 1847     Object Relational Dbms: Tracking the Next Grea...
# 4439     Rape of the Masses: The Psychology of Totalita...
# 1178                                The Call of the Canyon
# Name: Title, dtype: object

# %% [markdown]
# In this part, to find five most similar books to a given book. So using cosine similarity because it helps calculating angles between the vectors which means that it finds the most similar.

# %% [markdown]
# ## b)

# %% [markdown]
# Devise a method to quantify the quality of selection of books you return.  This could include external validation (e.g. comparing your recommendations against another type of recommendation), robustness testing (e.g. comparing the recommendations of two or more of your own different models), or other types of testing.

# %% [markdown]
# In order to test the model, using chatGPT and asking most similar books to Wonderful Worship in Smaller Churches. According to the ChatGPT, The Small Church Advantage, Shepherding the Small Church, Help for the Small-Church Pastor, No Little Places: The Untapped Potential of the Small-Town Church and The Purpose Driven Church. So according to the ChatGPT, it provided more church and worship realted books. The answers that the algithm provided are also kind of about churches and faith. So, it kind of correct to say the alrithm provided above works.

# %% [markdown]
# # Part 2: Composite Book Ratings

# %% [markdown]
# ## 1)

# %% [markdown]
# Determine a method to rate each book based on its user reviews. You can use any data available in the “Books_ratings.csv” file.

# %%
df2 = pd.read_csv("../data/Books_rating.csv")
df2 = df2.dropna().reset_index(drop=True)

# %%
df2 = df2.sample(n=50000, random_state=1)
df2.head()
# Out:
#                 Id                                              Title  Price  \
# 264037  0310579503                 Zondervan NIV Nave's Topical Bible  19.79
# 41275   1850896429                         Mrs. Miniver (Isis Series)  46.75
# 123666  1931599351  The Great Iowa Touring Book: 27 Spectacular Au...  21.95
# 290427  1421808803                                      Night And Day  41.95
# 388818  0486438767  Fashions of the Old South Coloring Book (Dover...   3.99
#
#                User_id             profileName review/helpfulness  \
# 264037  A2AW8SZYZTK86B  Paul Powell "moloch16"                1/1
# 41275   A3DNSXDSJRJY6T           J. A. Spilker                0/0
# 123666  A3FE8FQPQPONAW         Michelle Pettit              21/21
# 290427  A1H6VI6CMTOX3C              Book Lover                0/0
# 388818  A2T87CHZR3TE5E            Konrad Trope                0/0
#
#         review/score  review/time                         review/summary  \
# 264037           5.0   1303344000                         Great Resource
# 41275            5.0   1196294400                    A perennial classic
# 123666           5.0   1096329600     Wonderful information and accuracy
# 290427           2.0   1249862400                          Night and Day
# 388818           5.0   1201046400  Another beautiful Dover coloring book
#
#                                               review/text
# 264037  This is an great topical reference, I use it q...
# 41275   I re-read this book every year at the start of...
# 123666  I don't know how I stumbled on this book but I...
# 290427  I was very disappointed in this book. The plot...
# 388818  Beautiufl coloring book. I bought these for my...

# %% [markdown]
# ### a)

# %% [markdown]
# Perform your own analysis on the sentiment of the reviews in the data set.
# Compare your sentiment scores against the reviewer’s personal ratings.

# %%
df2['review/text'] = df2['review/text'].dropna()
df2['Title'] = df2['Title'].dropna()
df2.reset_index(drop=True)
# df2.head()
# Out:
#                 Id                                              Title  Price  \
# 264037  0310579503                 Zondervan NIV Nave's Topical Bible  19.79
# 41275   1850896429                         Mrs. Miniver (Isis Series)  46.75
# 123666  1931599351  The Great Iowa Touring Book: 27 Spectacular Au...  21.95
# 290427  1421808803                                      Night And Day  41.95
# 388818  0486438767  Fashions of the Old South Coloring Book (Dover...   3.99
#
#                User_id             profileName review/helpfulness  \
# 264037  A2AW8SZYZTK86B  Paul Powell "moloch16"                1/1
# 41275   A3DNSXDSJRJY6T           J. A. Spilker                0/0
# 123666  A3FE8FQPQPONAW         Michelle Pettit              21/21
# 290427  A1H6VI6CMTOX3C              Book Lover                0/0
# 388818  A2T87CHZR3TE5E            Konrad Trope                0/0
#
#         review/score  review/time                         review/summary  \
# 264037           5.0   1303344000                         Great Resource
# 41275            5.0   1196294400                    A perennial classic
# 123666           5.0   1096329600     Wonderful information and accuracy
# 290427           2.0   1249862400                          Night and Day
# 388818           5.0   1201046400  Another beautiful Dover coloring book
#
#                                               review/text
# 264037  This is an great topical reference, I use it q...
# 41275   I re-read this book every year at the start of...
# 123666  I don't know how I stumbled on this book but I...
# 290427  I was very disappointed in this book. The plot...
# 388818  Beautiufl coloring book. I bought these for my...

# %%
df2 = df2.dropna(subset=['Title', 'review/text']).reset_index(drop=True)
df2['review/text'] = df2['review/text'] + ' ' + df2['review/summary']

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
import nltk
nltk.download('vader_lexicon')

sid = SentimentIntensityAnalyzer()
df2['scores'] = df2['review/text'].astype(str).apply(lambda text: sid.polarity_scores(text))
df2['compound'] = df2['scores'].apply(lambda d: d['compound'])
df2['compound'] = df2['compound'].astype(float)
df2['sentiment'] = df2['compound'].apply(lambda score: 1 if score > 0.2 else -1 if score < -0.6 else 0)
df2[:10]
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/muratguzelocak/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
#            Id                                              Title  Price  \
# 0  0310579503                 Zondervan NIV Nave's Topical Bible  19.79
# 1  1850896429                         Mrs. Miniver (Isis Series)  46.75
# 2  1931599351  The Great Iowa Touring Book: 27 Spectacular Au...  21.95
# 3  1421808803                                      Night And Day  41.95
# 4  0486438767  Fashions of the Old South Coloring Book (Dover...   3.99
# 5  B000ETQQ3C                 The Center of Everything : A Novel   5.60
# 6  0764535463                       Flash 5 Weekend Crash Course  24.99
# 7  158297327X  Description & Setting: Techniques and Exercise...  11.35
# 8  0764200720                            A Bride Most Begrudging  10.19
# 9  0833585568  Maniac Magee (Turtleback School & Library Bind...  14.35
#
#           User_id               profileName review/helpfulness  review/score  \
# 0  A2AW8SZYZTK86B    Paul Powell "moloch16"                1/1           5.0
# 1  A3DNSXDSJRJY6T             J. A. Spilker                0/0           5.0
# 2  A3FE8FQPQPONAW           Michelle Pettit              21/21           5.0
# 3  A1H6VI6CMTOX3C                Book Lover                0/0           2.0
# 4  A2T87CHZR3TE5E              Konrad Trope                0/0           5.0
# 5  A1AYJ89PH08UH8                    Amanda                3/3           5.0
# 6   AGNEM2S9P40YV  John K. Gowrie "jgowrie"                2/2           1.0
# 7  A3E2GGJSQINKA3    Mike Klaassen "Author"                2/7           4.0
# 8  A2XL0GC44S709S               Chris Balan                1/1           5.0
# 9  A228JPM662A9OL            Luke skywalker                0/0           5.0
#
#    review/time                                     review/summary  \
# 0   1303344000                                     Great Resource
# 1   1196294400                                A perennial classic
# 2   1096329600                 Wonderful information and accuracy
# 3   1249862400                                      Night and Day
# 4   1201046400              Another beautiful Dover coloring book
# 5   1074038400                                     Excellent read
# 6   1007856000  Typos, Missing Steps and bad writing plague th...
# 7   1163980800                      WELL WORTH THE PURCHASE PRICE
# 8   1269302400                                    Loved this book
# 9   1352332800                                        Manic Magee
#
#                                          review/text  \
# 0  This is an great topical reference, I use it q...
# 1  I re-read this book every year at the start of...
# 2  I don't know how I stumbled on this book but I...
# 3  I was very disappointed in this book. The plot...
# 4  Beautiufl coloring book. I bought these for my...
# 5  I am always looking for a good book to read, a...
# 6  After getting through the first 50 pages of th...
# 7  The Description & Setting volume for the Write...
# 8  I was not sure I would like this book, even af...
# 9  Manic Magee Diesel Hayes#8Manic Magee AKA: Jef...
#
#                                               scores  compound  sentiment
# 0  {'neg': 0.0, 'neu': 0.691, 'pos': 0.309, 'comp...    0.8834          1
# 1  {'neg': 0.0, 'neu': 0.702, 'pos': 0.298, 'comp...    0.9670          1
# 2  {'neg': 0.0, 'neu': 0.733, 'pos': 0.267, 'comp...    0.9939          1
# 3  {'neg': 0.173, 'neu': 0.746, 'pos': 0.081, 'co...   -0.4765          0
# 4  {'neg': 0.0, 'neu': 0.655, 'pos': 0.345, 'comp...    0.9022          1
# 5  {'neg': 0.03, 'neu': 0.726, 'pos': 0.243, 'com...    0.9142          1
# 6  {'neg': 0.143, 'neu': 0.821, 'pos': 0.036, 'co...   -0.8850         -1
# 7  {'neg': 0.0, 'neu': 0.698, 'pos': 0.302, 'comp...    0.9559          1
# 8  {'neg': 0.09, 'neu': 0.682, 'pos': 0.228, 'com...    0.9238          1
# 9  {'neg': 0.083, 'neu': 0.847, 'pos': 0.07, 'com...    0.1280          0

# %%
df2['sentiment'].value_counts()
# Out:
# sentiment
#  1    42006
# -1     4102
#  0     3892
# Name: count, dtype: int64

# %%
df2['review/score'].value_counts()
# Out:
# review/score
# 5.0    30692
# 4.0     9525
# 3.0     4034
# 1.0     3268
# 2.0     2481
# Name: count, dtype: int64

# %% [markdown]
# In this part, using Sentiment analysis to understand which books got positive comments and which books got negative comments. In sentiment analysis, I created three groups: 1, 0, and -1. ! stands for possitive comments, 0 for neutral, and -1 for negative comments. According to the books data provided, sentiment analysis found 42006 posstive reviews, 3892 neutral comments, and 4102 negative comments.

# %% [markdown]
# ### b)

# %%
wrong = df2[((df2['review/score'] >= 4) & (df2['sentiment'] == -1)) | ((df2['review/score'] <= 2) &
         (df2['sentiment'] == 1)) | ((df2['review/score'] == 3) & (df2['sentiment'] != 0))]

accuracy = 1 - (len(wrong) / len(df2))
print(f"Accuracy Rate: {accuracy:.2%}")
# Out:
# Accuracy Rate: 83.26%

# %% [markdown]
# In this part in order to test our results from Sentiment Analysis, I assumed that review scores 5 and 4 are posstive comments, and 2 and below are negative comments. 3 comments' scores are neutral. According to this assumtion, this models' succes rate is $83.26\%$. Becuase it is above $80\%$, I think our model is succesfull.

# %% [markdown]
# ## 2)

# %% [markdown]
# ### a)

# %%
average = df2.groupby('Title')['review/score'].mean().reset_index() 
average = average.rename(columns={'review/score': 'averageScore'})
# average
# Out:
#                                                    Title  averageScore
# 0      "Cool Stuff" They Should Teach in School: Crui...      4.500000
# 1      "Forget Not Love": The Passion of Maximilian K...      5.000000
# 2      "I Want to Be Jesus!": Over 150 Easy-To-Use Go...      5.000000
# 3      "Let's Face it, Men are @$#%": What Women Can ...      1.000000
# 4                "Life Was Never Meant to Be a Struggle"      5.000000
# ...                                                  ...           ...
# 19277      sendmail Desktop Reference (Pocket Reference)      5.000000
# 19278                                        st*rf*ck*ng      5.000000
# 19279                         the Picture of Dorian Gray      4.151515
# 19280                               tick, tick ... BOOM!      4.000000
# 19281           to forgive...but not forget maja's story      5.000000
#
# [19282 rows x 2 columns]

# %%
df = df.reset_index(drop=True)
df2 = df2.reset_index(drop=True)
review_dict = {}
for i in range(len(df2)):
    if df2['Title'][i] not in review_dict.keys():
        review_dict[str(df2['Title'][i])] = df2['review/text'][i]
    else:
        review_dict[str(df2['Title'][i])] += " " 
        review_dict[str(df2['Title'][i])] += df2['review/text'][i]

# %%
df3 = pd.DataFrame(list(review_dict.items()), columns=['book_title', 'full_review'])
df3 = pd.merge(df3, average, right_on='Title' ,left_on='book_title', how='inner')
df3 = df3.drop(columns=['Title'])
df3
# Out:
#                                               book_title  \
# 0                     Zondervan NIV Nave's Topical Bible
# 1                             Mrs. Miniver (Isis Series)
# 2      The Great Iowa Touring Book: 27 Spectacular Au...
# 3                                          Night And Day
# 4      Fashions of the Old South Coloring Book (Dover...
# ...                                                  ...
# 19277                               Mazes (Shire Albums)
# 19278                                 The Stones Cry Out
# 19279  The Unanswered Question: Six Talks at Harvard ...
# 19280                                     Doubt!! Vol. 1
# 19281       Macroeconomics : A Neoclassical Introduction
#
#                                              full_review  averageScore
# 0      This is an great topical reference, I use it q...        4.2500
# 1      I re-read this book every year at the start of...        5.0000
# 2      I don't know how I stumbled on this book but I...        5.0000
# 3      I was very disappointed in this book. The plot...        3.4375
# 4      Beautiufl coloring book. I bought these for my...        5.0000
# ...                                                  ...           ...
# 19277  This is one of the most interesting Christmas ...        4.0000
# 19278  "and his face resembled a skeleton of wires co...        5.0000
# 19279  I respect Bernstein even more as a scholar of ...        5.0000
# 19280  'Doubt!!' revolves around 15-year-old, Ai Maek...        4.0000
# 19281  This book is not for lay people or even underg...        4.0000
#
# [19282 rows x 3 columns]

# %%
sid = SentimentIntensityAnalyzer()  # Create SentimentIntensityAnalyzer object
df3['scores'] = df3['full_review'].astype(str).apply(lambda text: sid.polarity_scores(text))
df3['compound'] = df3['scores'].apply(lambda d: d['compound'])
df3['compound'] = df3['compound'].astype(float)
df3['sentiment'] = df3['compound'].apply(lambda score: 1 if score > 0.2 else -1 if score < -0.6 else 0)
df3[:16]
# Out:
#                                            book_title  \
# 0                  Zondervan NIV Nave's Topical Bible
# 1                          Mrs. Miniver (Isis Series)
# 2   The Great Iowa Touring Book: 27 Spectacular Au...
# 3                                       Night And Day
# 4   Fashions of the Old South Coloring Book (Dover...
# 5                  The Center of Everything : A Novel
# 6                        Flash 5 Weekend Crash Course
# 7   Description & Setting: Techniques and Exercise...
# 8                             A Bride Most Begrudging
# 9   Maniac Magee (Turtleback School & Library Bind...
# 10  The Picture of Dorian Gray (Classic Collection...
# 11  Process Mastering: How to Establish and Docume...
# 12                             From Russia, With Love
# 13  Close Encounters With the Religious Right: Jou...
# 14                           Jane Eyre (New Windmill)
# 15                                 Crossing: A Memoir
#
#                                           full_review  averageScore  \
# 0   This is an great topical reference, I use it q...      4.250000
# 1   I re-read this book every year at the start of...      5.000000
# 2   I don't know how I stumbled on this book but I...      5.000000
# 3   I was very disappointed in this book. The plot...      3.437500
# 4   Beautiufl coloring book. I bought these for my...      5.000000
# 5   I am always looking for a good book to read, a...      3.896552
# 6   After getting through the first 50 pages of th...      1.000000
# 7   The Description & Setting volume for the Write...      3.750000
# 8   I was not sure I would like this book, even af...      3.882353
# 9   Manic Magee Diesel Hayes#8Manic Magee AKA: Jef...      3.944444
# 10  It is very easy to see why this novel is a cla...      4.313725
# 11  I found Process Mastering to be a very valuabl...      5.000000
# 12  Ian Fleming's James Bond novels are certainly ...      4.333333
# 13  I know its a bad anthology but just look at hi...      5.000000
# 14  Charlotte Bronte's Jane Eyre, the subject of m...      4.484615
# 15  This is the story of one Donald McCloskey, a b...      4.000000
#
#                                                scores  compound  sentiment
# 0   {'neg': 0.012, 'neu': 0.791, 'pos': 0.196, 'co...    0.9880          1
# 1   {'neg': 0.0, 'neu': 0.702, 'pos': 0.298, 'comp...    0.9670          1
# 2   {'neg': 0.0, 'neu': 0.733, 'pos': 0.267, 'comp...    0.9939          1
# 3   {'neg': 0.078, 'neu': 0.73, 'pos': 0.192, 'com...    0.9999          1
# 4   {'neg': 0.009, 'neu': 0.667, 'pos': 0.324, 'co...    0.9952          1
# 5   {'neg': 0.09, 'neu': 0.716, 'pos': 0.194, 'com...    0.9999          1
# 6   {'neg': 0.143, 'neu': 0.821, 'pos': 0.036, 'co...   -0.8850         -1
# 7   {'neg': 0.057, 'neu': 0.765, 'pos': 0.178, 'co...    0.9965          1
# 8   {'neg': 0.081, 'neu': 0.686, 'pos': 0.233, 'co...    0.9999          1
# 9   {'neg': 0.112, 'neu': 0.717, 'pos': 0.17, 'com...    0.9997          1
# 10  {'neg': 0.098, 'neu': 0.715, 'pos': 0.187, 'co...    1.0000          1
# 11  {'neg': 0.009, 'neu': 0.797, 'pos': 0.194, 'co...    0.9910          1
# 12  {'neg': 0.099, 'neu': 0.708, 'pos': 0.193, 'co...    0.9995          1
# 13  {'neg': 0.223, 'neu': 0.655, 'pos': 0.122, 'co...   -0.9934         -1
# 14  {'neg': 0.077, 'neu': 0.681, 'pos': 0.243, 'co...    1.0000          1
# 15  {'neg': 0.048, 'neu': 0.81, 'pos': 0.142, 'com...    0.9980          1

# %%
df3.sort_values(by='compound', ascending=False)[:16]
# Out:
#                                              book_title  \
# 830   Bringing Down the House: The Inside Story of S...
# 523                             Jane Eyre (Large Print)
# 1536                   Attila: A Barbarian's Love Story
# 832   Year of Wonders (Turtleback School & Library B...
# 835                                           Plainsong
# 1523                             Before the Season Ends
# 309         Gods and Kings (Chronicles of the Kings #1)
# 94                                           Persuasion
# 1313  Left to Tell: Discovering God Amidst The Rwand...
# 2030  The Bread Lover's Bread Machine Cookbook: A Ma...
# 507                          the Picture of Dorian Gray
# 316   Sense And Sensibility (CH) (Jane Austen Collec...
# 604   Don't Make Me Think: A Common Sense Approach t...
# 248                                     Treasure Island
# 855   A Christmas Carol, in Prose: Being a Ghost Sto...
# 165                        Eldest (Inheritance, Book 2)
#
#                                             full_review  averageScore  \
# 830   I liked this book because it is true. Often ti...      4.309524
# 523   Best book I've had the pleasure of reading in ...      4.608696
# 1536  ATTILA: A BARBARIAN'S LOVE STORYThe book's str...      4.600000
# 832   I could not put this book down. Very well writ...      4.038462
# 835   I found Plainsong to be a wonderfully evocativ...      3.820000
# 1523  Linore Rose Burkard has created an entertainin...      4.428571
# 309   I greatly enjoy reading the books of history f...      4.685714
# 94    I had been very Curiousabout is book after see...      4.295455
# 1313  I was assigned to read this book for class, an...      4.792683
# 2030  I love this book and highly recommend it! It i...      4.296296
# 507   My grown daughter bought this for me as a Chri...      4.151515
# 316   A wonderful Jane Austen book. This is one of m...      4.431373
# 604   Very useful information, but like many books b...      4.707317
# 248   The main character is Jim and the book is abou...      4.491525
# 855   I would have given this book a good rating bef...      4.762295
# 165   I started reading the Paolini books after I wa...      3.738854
#
#                                                  scores  compound  sentiment
# 830   {'neg': 0.061, 'neu': 0.743, 'pos': 0.196, 'co...       1.0          1
# 523   {'neg': 0.08, 'neu': 0.685, 'pos': 0.235, 'com...       1.0          1
# 1536  {'neg': 0.067, 'neu': 0.685, 'pos': 0.248, 'co...       1.0          1
# 832   {'neg': 0.089, 'neu': 0.727, 'pos': 0.184, 'co...       1.0          1
# 835   {'neg': 0.078, 'neu': 0.745, 'pos': 0.177, 'co...       1.0          1
# 1523  {'neg': 0.052, 'neu': 0.656, 'pos': 0.292, 'co...       1.0          1
# 309   {'neg': 0.047, 'neu': 0.725, 'pos': 0.228, 'co...       1.0          1
# 94    {'neg': 0.074, 'neu': 0.724, 'pos': 0.201, 'co...       1.0          1
# 1313  {'neg': 0.105, 'neu': 0.667, 'pos': 0.228, 'co...       1.0          1
# 2030  {'neg': 0.051, 'neu': 0.772, 'pos': 0.177, 'co...       1.0          1
# 507   {'neg': 0.107, 'neu': 0.712, 'pos': 0.181, 'co...       1.0          1
# 316   {'neg': 0.064, 'neu': 0.712, 'pos': 0.223, 'co...       1.0          1
# 604   {'neg': 0.041, 'neu': 0.756, 'pos': 0.203, 'co...       1.0          1
# 248   {'neg': 0.062, 'neu': 0.715, 'pos': 0.223, 'co...       1.0          1
# 855   {'neg': 0.049, 'neu': 0.718, 'pos': 0.233, 'co...       1.0          1
# 165   {'neg': 0.092, 'neu': 0.735, 'pos': 0.173, 'co...       1.0          1

# %% [markdown]
# In this part, I combined the all the `review/text` under one book `title`. I, also, averaged the `review/score` under the name of 'averageScore'. In this part, because we generilize the data more I expect higher accuracy score.

# %% [markdown]
# ### b)

# %%
wrong = df3[((df3['averageScore'] >= 4) & (df3['sentiment'] == -1)) | ((df3['averageScore'] <= 2) &
         (df3['sentiment'] == 1)) | ((df3['averageScore'] == 3) & (df3['sentiment'] != 0))]

accuracy = 1 - (len(wrong) / len(df3))
print(f"Accuracy Rate: {accuracy:.2%}")
# Out:
# Accuracy Rate: 86.70%

# %% [markdown]
# In this part I used the same technique from the previous section to calcualte the accuracy rate. Combinning reviews under one `book_title`, and getting the averages of the `review/score` helped more than $3\%$. So, new accuracy rate is $86.7\%$, which is significant.

# %% [markdown]
# # Part 3: A comprehensive recommender system

# %% [markdown]
# ## a)

# %%
finalDF = pd.merge(df, df3, how='inner', left_on='Title', right_on='book_title')
finalDF = finalDF.drop(columns=['book_title', 'scores', 'image', 'previewLink', 'authors', 'categories',
                                 'description', 'publisher', 'publishedDate', 'infoLink'])
finalDF = finalDF[finalDF['sentiment'] != -1]
finalDF = finalDF.reset_index(drop=True)
finalDF
# Out:
#                                                    Title  ratingsCount  \
# 0                          Whispers of the Wicked Saints           NaN
# 1                            Dramatica for Screenwriters           NaN
# 2      The Ultimate Guide to Law School Admission: In...           NaN
# 3       Beginner's Yoruba (Hippocrene Beginner's Series)           1.0
# 4      How to Discipline Kids without Losing Their Lo...           1.0
# ...                                                  ...           ...
# 13799                                El color del verano           NaN
# 13800  In the First Line of Battle: The 12th Illinois...           NaN
# 13801  Is Your Retirement Heading in the Right Direct...           NaN
# 13802  The Awakening and Selected Stories (Modern Lib...           2.0
# 13803  The Magic of the Soul: Applying Spiritual Powe...           NaN
#
#                                              combination  \
# 0      Julia Thomas finds her life spinning out of co...
# 1      Dramatica for Screenwriters by Armando Saldana...
# 2      This collection brings together a distinguishe...
# 3      "Beginner's Yoruba" is now available with two ...
# 4      Imagine... No More Arguing. Imagine... No More...
# ...                                                  ...
# 13799  Es pleno verano y en la isla de Cuba comienza ...
# 13800  From its first major engagement at Harpers Fer...
# 13801  So many seniors today are living so much longe...
# 13802  WHEN IT FIRST APPEARED IN 1899, THE AWAKENING ...
# 13803  "The Magic of the Soul, Applying Spiritual Pow...
#
#                                              full_review  averageScore  \
# 0      Just as predicted the first chapter of the boo...          4.75
# 1      Beauty is in the bones. This book gives your s...          5.00
# 2      If you have even casually looked into applying...          1.00
# 3      This is my first encounter with Yoruba and I h...          4.00
# 4      I purchased this book not knowing much about i...          5.00
# ...                                                  ...           ...
# 13799  Since I read the first chapter of the book I w...          5.00
# 13800  It had been traditional that a member of a mil...          5.00
# 13801  this book was very unrewarding in terms of sol...          1.00
# 13802  I actually haven't reached the Awakening yet. ...          3.50
# 13803  I often disagree with things that Patrick says...          4.50
#
#        compound  sentiment
# 0        0.9984          1
# 1        0.9972          1
# 2        0.4434          1
# 3        0.9653          1
# 4        0.9963          1
# ...         ...        ...
# 13799    0.4836          1
# 13800   -0.1635          0
# 13801    0.5994          1
# 13802    0.9206          1
# 13803    0.9982          1
#
# [13804 rows x 7 columns]

# %%
get_most_similar('Whispers of the Wicked Saints')
# Out:
# 29778                           Women in the Wind
# 38466                        An Independent Woman
# 119844                 Miss Julia Speaks Her Mind
# 37156                        At Mrs. Lippincote's
# 94218     When a Texan Gambles (The Wife Lottery)
# Name: Title, dtype: object

# %%
v = CountVectorizer(stop_words = 'english')

X = v.fit_transform(finalDF['combination']) #creates a vocabulary and creates the data
book2idx = pd.Series(finalDF.index, index=finalDF['Title'])
def get_best_book(book_title):
    if book_title in book2idx.keys():
        idx = book2idx[book_title]
        scores = cosine_similarity(X, X[idx])
        # Now we want to find the best matches. We're not actually interested in the scores themselves, but the relative rankings.
        # For that, we can use the argsort command.
        # scores.argsort() would sort the scores in ascending order and then return the indices that correspond to those scores.
        # Since we want the highest scores, I'll use (-scores).argsort() instead.
        scores = scores.flatten()
        recommended = (-scores).argsort()

        # We should ignore the first entry in the list (since that'll be the movie itself).
        # Let's take the next 5 movies.
        recommended = recommended[1:6]

        # Now we should return the titles of the corresponding movies.
        return finalDF['Title'].iloc[recommended]
    else:
        return "Book not found"

# %%
get_best_book('Whispers of the Wicked Saints')
# Out:
# 9529               When a Texan Gambles (The Wife Lottery)
# 10647                                       Healing H'Arts
# 4754                                     My Life in France
# 13570    It Will Live Forever: Traditional Yosemite Ind...
# 2670     Inconceivable: A Woman's Triumph over Despair ...
# Name: Title, dtype: object

# %% [markdown]
# In this part, to combine two different analysis techniques to make better book recomandations, I decided to remove all the books with negative sentiment analysis book score from the data so our users don't get recommendations of unliked books. Than I just kept everything else same.

# %% [markdown]
# ## b)

# %%
while True:
  book_title = input("Enter a book title: or hit 'q' to quit")
  if book_title == 'q':
    print("Goodbye!")
    break
  print(f"{book_title} is similar to:\n")
  print(get_best_book(book_title))
  print("\n")
# Out:
# Wonderful Worship in Smaller Churches is similar to:
#
# Book not found
#
#
# Healing H'Arts is similar to:
#
# 4754                                     My Life in France
# 10025                                       Power Mandalas
# 13570    It Will Live Forever: Traditional Yosemite Ind...
# 0                            Whispers of the Wicked Saints
# 6469                                         Inconceivable
# Name: Title, dtype: object
#
#
# Goodbye!

# %% [markdown]
# In this part, I provided users with simple console based book finder.
